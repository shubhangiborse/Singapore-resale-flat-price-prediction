# %%
# imported import liberaries
import glob
import pandas as pd
import json
import requests


import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import datetime as dt

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio


import warnings
warnings.filterwarnings('ignore')

# %%
glob.glob("*.csv")

# %%
# five csv files grouping together
#Importing and Loading the datasets
# *.csv is used to get the files from outside the folder

df = pd.concat([pd.read_csv(f) for f in glob.glob("*.csv")], ignore_index=True)
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
df.describe().T  #quick overview of the data

# %%
 #returns the count of all unique values in the given index in descending order, without any null values
df['resale_price'].value_counts()

# %% [markdown]
# **Data cleaning**

# %%
 #to count the number of unique values in each column of a DataFrame
df.nunique()

# %%
#to count the number of missing (NaN) values in each column of a DataFrame
#Handling Null Values
df.isna().sum()

# %%
# coverting reamining_lease colume (91 years 01 months) time date format
def convert_to_years(row):
    if pd.notna(row) and isinstance(row, str):
        if 'years' in row:
            parts = row.split()
            years = float(parts[0])
            months = float(parts[2]) if len(parts) > 2 else 0
            return years + months / 12
    return row

# %%
df['remaining_lease'] =df['remaining_lease'].apply(convert_to_years)

# %%
# fill null values in remaining_lease with mode beacuse null value more than 25% it will remove affected in accuracy
df['remaining_lease']=df['remaining_lease'].fillna(df['remaining_lease'].mode()[0])
df.tail()

# %%
df['remaining_lease'].value_counts()

# %%
df.isnull().sum()

# %% [markdown]
# **Wrong Formate**

# %%
df.dtypes

# %%
#Month column

# Separate the year and month of resale beacuse this is time series Data
df[['resale_year', 'resale_month']] =df['month'].str.split('-', expand=True)

# drop the resale month column
df.drop('month', axis = 1, inplace= True)

df.head(2)

# %%
# Split the 'Range' column into lower and upper bounds
df[['storey_lower_bound', 'storey_upper_bound']] = df['storey_range'].str.split(' TO ', expand=True)

# Convert the lower and upper bounds to numeric values
df['storey_lower_bound'] = pd.to_numeric(df['storey_lower_bound'])
df['storey_upper_bound'] = pd.to_numeric(df['storey_upper_bound'])

df.tail(2)

# %%
df.drop('storey_range', axis = 1, inplace= True)

# %%
# CONVERTING

df['block'] = pd.to_numeric(df['block'], errors='coerce')
df['resale_year'] = pd.to_numeric(df['resale_year'], errors='coerce')
df['resale_month'] = pd.to_numeric(df['resale_month'], errors='coerce')
df['block'] = df['block'].fillna(df['block'].mode()[0])

# %%
df.head()

# %%
df.dtypes

# %% [markdown]
# ** Text error**

# %%
object_data_cols = [var for var in df.columns if df[var].dtype == 'object']
object_data_cols

# %%
df['town'].value_counts()

# %%
df['flat_type'].value_counts()

# %%
# Replace 'MULTI-GENERATION' with 'MULTI GENERATION' in the specified column to avoid duplicate
df['flat_type'] = df['flat_type'].str.replace('MULTI-GENERATION', 'MULTI GENERATION')

# %%
df['flat_type'].value_counts()

# %%
df['street_name'].value_counts()

# %%
df['flat_model'].value_counts()

# %%
df['flat_model'] = df['flat_model'].replace({'MODEL A':'Model A','NEW GENERATION':'New Generation',
                                             'IMPROVED':'Improved','PREMIUM APARTMENT':'Premium Apartment',
                                             'MULTI GENERATION':'Multi Generation ','2-ROOM':'2-room',
                                            'SIMPLIFIED':'Simplified','STANDARD':'Standard',
                                             'MAISONETTE':'Maisonette','MULTI GENERATION':'Multi Generation',
                                             'APARTMENT':'Apartment','MODEL A-MAISONETTE':'Model A-Maisonette',
                                             'TERRACE':'Terrace','IMPROVED-MAISONETTE':'Improved-Maisonette'})

# %%
df['flat_model'].value_counts()

# %% [markdown]
# ** duplicates**

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()

# %% [markdown]
# **Outliers**

# %%
float_data_cols = [var for var in df.columns if df[var].dtype == 'float64']
float_data_cols

# %%
integer_data_cols = [var for var in df.columns if df[var].dtype == 'int64']
integer_data_cols

# %% [markdown]
# ** using boxplot**

# %%
# Creating plot
plt.boxplot(df['block'])

# show plot
plt.show()

# %%
# IQR

Q1 = df['block'].quantile(0.25)
Q3 = df['block'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound

# %%
df.block = df.block.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['block'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['floor_area_sqm'] )

# show plot
plt.show()

# %%
Q1 = df['floor_area_sqm'].quantile(0.25)
Q3 = df['floor_area_sqm'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound

# %%
df.floor_area_sqm = df.floor_area_sqm.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['floor_area_sqm'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['resale_price'] )

# show plot
plt.show()

# %%
Q1 = df['resale_price'].quantile(0.25)
Q3 = df['resale_price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound

# %%
df.resale_price = df.resale_price.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['resale_price'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['remaining_lease'] )

# show plot
plt.show()

# %%
Q1 = df['remaining_lease'].quantile(0.25)
Q3 = df['remaining_lease'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound

# %%
df.remaining_lease = df.remaining_lease.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['remaining_lease'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['lease_commence_date'] )

# show plot
plt.show()

# %%
Q1 = df['lease_commence_date'].quantile(0.25)
Q3 = df['lease_commence_date'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (1958.5, 2018.5)

# %%
df.lease_commence_date = df.lease_commence_date.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['lease_commence_date'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['storey_lower_bound'] )

# show plot
plt.show()

# %%
Q1 = df['storey_lower_bound'].quantile(0.25)
Q3 = df['storey_lower_bound'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (-5.0, 19.0)

# %%
df.storey_lower_bound = df.storey_lower_bound.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['storey_lower_bound'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['storey_upper_bound'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(df['storey_upper_bound'] )

# show plot
plt.show()

# %%
Q1 = df['storey_upper_bound'].quantile(0.25)
Q3 = df['storey_upper_bound'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (-3.0, 21.0)

# %%
df.storey_upper_bound = df.storey_upper_bound.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(df['storey_upper_bound'] )

# show plot
plt.show()

# %% [markdown]
# EDA - EXPLORATARY DATA ANALYSIS
#
# Categorical Vs Frequency using BarPlot

# %%
object_data_cols = [var for var in df.columns if df[var].dtype == 'object']
object_data_cols
# Out:
# ['town', 'flat_type', 'street_name', 'flat_model']

# %%
plt.figure(figsize=(20, 25))



plt.subplot(431)
df['town'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('town')
plt.xlabel('town')
plt.ylabel('Frequency')
plt.xticks(rotation=15)

plt.subplot(432)
df['flat_type'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('flat_type')
plt.xlabel('flat_type')
plt.ylabel('Frequency')

plt.subplot(433)
df['street_name'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('street_name')
plt.xlabel('street_name')
plt.ylabel('Frequency')

plt.subplot(434)
df['flat_model'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('flat_model')
plt.xlabel('flat_model')
plt.ylabel('Frequency')

plt.subplot(435)
df['resale_year'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('resale_year')
plt.xlabel('resale_year')
plt.ylabel('Frequency')

plt.subplot(436)
df['resale_month'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('resale_month')
plt.xlabel('resale_month')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Feature Vs Target (Categorical Data )

# %%
# List of features to plot
features = [
    'town',
 'flat_type',
 'street_name',
 'flat_model',
 'resale_year',
 'resale_month'
]
for feature in features:
    plt.figure(figsize=(10, 6))
    df.groupby(feature)['resale_price'].mean().plot(kind='bar')
    plt.xlabel(feature)
    plt.ylabel('Mean resale_price')
    plt.title(f'{feature} vs Mean Flight_Price')
    plt.show()

# %% [markdown]
# Feature Vs Target (Condinues Data )

# %%
float_data_cols = [var for var in df.columns if df[var].dtype == 'float64']
float_data_cols
# Out:
# ['block',
#  'floor_area_sqm',
#  'lease_commence_date',
#  'resale_price',
#  'remaining_lease']

# %%
integer_data_cols = [var for var in df.columns if df[var].dtype == 'int64']
integer_data_cols
# Out:
# ['resale_year', 'resale_month', 'storey_lower_bound', 'storey_upper_bound']

# %%
features = [ 'block',
 'floor_area_sqm',
 'lease_commence_date',
 'resale_price',
 'remaining_lease',
'storey_lower_bound',
'storey_upper_bound']
target = 'resale_price'
for feature in features:
    plt.figure(figsize=(10, 6))
    plt.scatter(df[feature], df[target], alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.title(f'{feature} vs {target}')
    plt.show()

# %% [markdown]
# Encoding Categorical Variables

# %%
#using encoding make a copy
df1=df.copy()

object_data_cols = [var for var in df.columns if df[var].dtype == 'object']
object_data_cols
# Out:
# ['town', 'flat_type', 'street_name', 'flat_model']

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize the Encoder
le= LabelEncoder()

# %%
# list unique street names
streets = df1['street_name'].unique()
# map the streets to povide input to ML model
streets_mapping = {street: idx + 1 for idx, street in enumerate(streets)}
streets_mapping
# Out:
# {'ANG MO KIO AVE 4': 1,
#  'ANG MO KIO AVE 1': 2,
#  'ANG MO KIO AVE 10': 3,
#  'ANG MO KIO AVE 2': 4,
#  'ANG MO KIO AVE 3': 5,
#  'ANG MO KIO AVE 5': 6,
#  'ANG MO KIO AVE 6': 7,
#  'ANG MO KIO AVE 8': 8,
#  'ANG MO KIO AVE 9': 9,
#  'ANG MO KIO ST 21': 10,
#  'ANG MO KIO ST 31': 11,
#  'ANG MO KIO ST 11': 12,
#  'BEDOK RESERVOIR RD': 13,
#  'BEDOK NTH RD': 14,
#  'BEDOK NTH ST 3': 15,
#  'BEDOK STH AVE 1': 16,
#  'BEDOK STH RD': 17,
#  'CHAI CHEE AVE': 18,
#  'NEW UPP CHANGI RD': 19,
#  'CHAI CHEE DR': 20,
#  'CHAI CHEE RD': 21,
#  'BEDOK NTH AVE 1': 22,
#  'BEDOK NTH AVE 2': 23,
#  'BEDOK NTH AVE 3': 24,
#  'BEDOK NTH AVE 4': 25,
#  'BEDOK NTH ST 1': 26,
#  'BEDOK NTH ST 2': 27,
#  'BEDOK NTH ST 4': 28,
#  'BEDOK STH AVE 2': 29,
#  'BEDOK STH AVE 3': 30,
#  'CHAI CHEE ST': 31,
#  'LENGKONG TIGA': 32,
#  'JLN TENAGA': 33,
#  'SIN MING RD': 34,
#  'SHUNFU RD': 35,
#  'BISHAN ST 11': 36,
#  'BISHAN ST 12': 37,
#  'BISHAN ST 13': 38,
#  'SIN MING AVE': 39,
#  'BISHAN ST 22': 40,
#  'BISHAN ST 23': 41,
#  'BISHAN ST 24': 42,
#  'BRIGHT HILL DR': 43,
#  'BT BATOK ST 51': 44,
#  'BT BATOK ST 52': 45,
#  'BT BATOK ST 11': 46,
#  'BT BATOK ST 21': 47,
#  'BT BATOK ST 34': 48,
#  'BT BATOK WEST AVE 4': 49,
#  'BT BATOK WEST AVE 8': 50,
#  'BT BATOK EAST AVE 4': 51,
#  'BT BATOK EAST AVE 5': 52,
#  'BT BATOK ST 31': 53,
#  'BT BATOK ST 32': 54,
#  'BT BATOK ST 33': 55,
#  'BT BATOK WEST AVE 6': 56,
#  'BT BATOK EAST AVE 3': 57,
#  'BT BATOK CTRL': 58,
#  'BT BATOK WEST AVE 2': 59,
#  'TAMAN HO SWEE': 60,
#  'TELOK BLANGAH CRES': 61,
#  'HOY FATT RD': 62,
#  'BT MERAH VIEW': 63,
#  'JLN BT MERAH': 64,
#  'KIM TIAN RD': 65,
#  'TELOK BLANGAH DR': 66,
#  'TELOK BLANGAH RISE': 67,
#  'TELOK BLANGAH WAY': 68,
#  'ZION RD': 69,
#  'BT PURMEI RD': 70,
#  'TELOK BLANGAH HTS': 71,
#  'BEO CRES': 72,
#  'HAVELOCK RD': 73,
#  'JLN BT HO SWEE': 74,
#  'JLN KLINIK': 75,
#  'REDHILL CL': 76,
#  'HENDERSON CRES': 77,
#  'BT MERAH CTRL': 78,
#  'DELTA AVE': 79,
#  'EVERTON PK': 80,
#  'KIM TIAN PL': 81,
#  'DEPOT RD': 82,
#  'SPOTTISWOODE PK RD': 83,
#  'GANGSA RD': 84,
#  'PENDING RD': 85,
#  'PETIR RD': 86,
#  'BANGKIT RD': 87,
#  'BT PANJANG RING RD': 88,
#  'FAJAR RD': 89,
#  'SAUJANA RD': 90,
#  'EMPRESS RD': 91,
#  "QUEEN'S RD": 92,
#  'TOH YI DR': 93,
#  'JLN KUKOH': 94,
#  'KELANTAN RD': 95,
#  'SAGO LANE': 96,
#  'TG PAGAR PLAZA': 97,
#  'CHANDER RD': 98,
#  'ROWELL RD': 99,
#  'VEERASAMY RD': 100,
#  'QUEEN ST': 101,
#  'ROCHOR RD': 102,
#  'KRETA AYER RD': 103,
#  'TECK WHYE AVE': 104,
#  'TECK WHYE LANE': 105,
#  'CHOA CHU KANG AVE 1': 106,
#  'CHOA CHU KANG AVE 2': 107,
#  'CHOA CHU KANG AVE 3': 108,
#  'CHOA CHU KANG AVE 4': 109,
#  'CHOA CHU KANG CTRL': 110,
#  'CHOA CHU KANG NTH 7': 111,
#  'CHOA CHU KANG ST 51': 112,
#  'CHOA CHU KANG ST 52': 113,
#  'CHOA CHU KANG ST 53': 114,
#  'CHOA CHU KANG ST 62': 115,
#  'CHOA CHU KANG NTH 5': 116,
#  'CHOA CHU KANG NTH 6': 117,
#  'CLEMENTI WEST ST 1': 118,
#  'CLEMENTI AVE 1': 119,
#  'CLEMENTI AVE 2': 120,
#  'CLEMENTI AVE 3': 121,
#  'CLEMENTI AVE 4': 122,
#  'CLEMENTI AVE 5': 123,
#  'CLEMENTI WEST ST 2': 124,
#  'WEST COAST DR': 125,
#  'WEST COAST RD': 126,
#  'CLEMENTI ST 13': 127,
#  'CLEMENTI AVE 6': 128,
#  'CIRCUIT RD': 129,
#  'GEYLANG SERAI': 130,
#  'JLN PASAR BARU': 131,
#  'ALJUNIED CRES': 132,
#  'EUNOS CRES': 133,
#  'HAIG RD': 134,
#  'PAYA LEBAR WAY': 135,
#  'SIMS DR': 136,
#  'SIMS PL': 137,
#  'DAKOTA CRES': 138,
#  'GEYLANG EAST AVE 1': 139,
#  'PINE CL': 140,
#  'UBI AVE 1': 141,
#  'BALAM RD': 142,
#  'MACPHERSON LANE': 143,
#  'ALJUNIED RD': 144,
#  'GEYLANG EAST CTRL': 145,
#  'EUNOS RD 5': 146,
#  'HOUGANG AVE 3': 147,
#  'HOUGANG AVE 8': 148,
#  'HOUGANG AVE 4': 149,
#  'HOUGANG AVE 5': 150,
#  'HOUGANG AVE 1': 151,
#  'HOUGANG AVE 10': 152,
#  'HOUGANG AVE 7': 153,
#  'HOUGANG ST 51': 154,
#  'HOUGANG ST 52': 155,
#  'HOUGANG ST 61': 156,
#  'LOR AH SOO': 157,
#  'HOUGANG AVE 2': 158,
#  'HOUGANG ST 11': 159,
#  'HOUGANG ST 22': 160,
#  'HOUGANG AVE 6': 161,
#  'HOUGANG CTRL': 162,
#  'HOUGANG ST 21': 163,
#  'TEBAN GDNS RD': 164,
#  'JURONG EAST ST 32': 165,
#  'JURONG EAST ST 13': 166,
#  'JURONG EAST ST 21': 167,
#  'JURONG EAST ST 24': 168,
#  'JURONG EAST AVE 1': 169,
#  'PANDAN GDNS': 170,
#  'JURONG EAST ST 31': 171,
#  'BOON LAY AVE': 172,
#  'BOON LAY DR': 173,
#  'BOON LAY PL': 174,
#  'HO CHING RD': 175,
#  'YUNG KUANG RD': 176,
#  'JURONG WEST AVE 1': 177,
#  'JURONG WEST ST 41': 178,
#  'JURONG WEST ST 42': 179,
#  'JURONG WEST ST 52': 180,
#  'JURONG WEST ST 91': 181,
#  'JURONG WEST ST 92': 182,
#  'JURONG WEST AVE 5': 183,
#  'JURONG WEST ST 71': 184,
#  'JURONG WEST ST 72': 185,
#  'JURONG WEST ST 73': 186,
#  'JURONG WEST ST 74': 187,
#  'JURONG WEST ST 75': 188,
#  'JURONG WEST ST 81': 189,
#  'YUNG AN RD': 190,
#  'JLN BATU': 191,
#  'BEACH RD': 192,
#  'BENDEMEER RD': 193,
#  'CRAWFORD LANE': 194,
#  'GEYLANG BAHRU': 195,
#  'KALLANG BAHRU': 196,
#  'LOR LIMAU': 197,
#  "ST. GEORGE'S RD": 198,
#  'UPP BOON KENG RD': 199,
#  'WHAMPOA DR': 200,
#  'WHAMPOA WEST': 201,
#  'GLOUCESTER RD': 202,
#  'JLN BAHAGIA': 203,
#  'LOR 3 GEYLANG': 204,
#  'RACE COURSE RD': 205,
#  'TOWNER RD': 206,
#  'JLN RAJAH': 207,
#  'KENT RD': 208,
#  "ST. GEORGE'S LANE": 209,
#  'AH HOOD RD': 210,
#  "KING GEORGE'S AVE": 211,
#  'MCNAIR RD': 212,
#  'WHAMPOA RD': 213,
#  'MARINE TER': 214,
#  'MARINE CRES': 215,
#  'MARINE DR': 216,
#  'ELIAS RD': 217,
#  'PASIR RIS DR 1': 218,
#  'PASIR RIS DR 3': 219,
#  'PASIR RIS DR 4': 220,
#  'PASIR RIS DR 6': 221,
#  'PASIR RIS ST 11': 222,
#  'PASIR RIS ST 12': 223,
#  'PASIR RIS ST 21': 224,
#  'PASIR RIS ST 52': 225,
#  'PASIR RIS ST 53': 226,
#  'PASIR RIS ST 71': 227,
#  'PASIR RIS DR 10': 228,
#  'PASIR RIS ST 13': 229,
#  'PASIR RIS ST 51': 230,
#  'PASIR RIS ST 72': 231,
#  'PASIR RIS ST 41': 232,
#  "C'WEALTH CL": 233,
#  "C'WEALTH DR": 234,
#  'TANGLIN HALT RD': 235,
#  'DOVER CRES': 236,
#  'GHIM MOH RD': 237,
#  'HOLLAND AVE': 238,
#  'HOLLAND CL': 239,
#  'HOLLAND DR': 240,
#  'MEI LING ST': 241,
#  'STIRLING RD': 242,
#  'DOVER RD': 243,
#  "C'WEALTH CRES": 244,
#  'CLARENCE LANE': 245,
#  'STRATHMORE AVE': 246,
#  'DOVER CL EAST': 247,
#  'SELETAR WEST FARMWAY 6': 248,
#  'LOR LEW LIAN': 249,
#  'SERANGOON AVE 2': 250,
#  'SERANGOON NTH AVE 1': 251,
#  'SERANGOON AVE 4': 252,
#  'SERANGOON CTRL': 253,
#  'SERANGOON AVE 1': 254,
#  'SERANGOON NTH AVE 4': 255,
#  'SERANGOON AVE 3': 256,
#  'SERANGOON NTH AVE 2': 257,
#  'TAMPINES ST 41': 258,
#  'TAMPINES AVE 4': 259,
#  'TAMPINES ST 11': 260,
#  'TAMPINES ST 12': 261,
#  'TAMPINES ST 21': 262,
#  'TAMPINES ST 22': 263,
#  'TAMPINES ST 23': 264,
#  'TAMPINES ST 24': 265,
#  'TAMPINES ST 42': 266,
#  'TAMPINES ST 44': 267,
#  'TAMPINES ST 82': 268,
#  'TAMPINES ST 83': 269,
#  'TAMPINES ST 84': 270,
#  'TAMPINES ST 91': 271,
#  'TAMPINES ST 81': 272,
#  'SIMEI RD': 273,
#  'SIMEI ST 1': 274,
#  'SIMEI ST 4': 275,
#  'TAMPINES AVE 5': 276,
#  'TAMPINES AVE 8': 277,
#  'TAMPINES AVE 9': 278,
#  'TAMPINES CTRL 1': 279,
#  'TAMPINES ST 33': 280,
#  'TAMPINES ST 34': 281,
#  'TAMPINES ST 45': 282,
#  'SIMEI ST 2': 283,
#  'TAMPINES AVE 7': 284,
#  'TAMPINES ST 32': 285,
#  'TAMPINES ST 43': 286,
#  'LOR 2 TOA PAYOH': 287,
#  'KIM KEAT AVE': 288,
#  'LOR 1 TOA PAYOH': 289,
#  'LOR 3 TOA PAYOH': 290,
#  'LOR 4 TOA PAYOH': 291,
#  'LOR 5 TOA PAYOH': 292,
#  'LOR 7 TOA PAYOH': 293,
#  'LOR 8 TOA PAYOH': 294,
#  'TOA PAYOH EAST': 295,
#  'TOA PAYOH NTH': 296,
#  'POTONG PASIR AVE 1': 297,
#  'POTONG PASIR AVE 2': 298,
#  'LOR 6 TOA PAYOH': 299,
#  'UPP ALJUNIED LANE': 300,
#  'TOA PAYOH CTRL': 301,
#  'JOO SENG RD': 302,
#  'KIM KEAT LINK': 303,
#  'POTONG PASIR AVE 3': 304,
#  'MARSILING DR': 305,
#  'MARSILING LANE': 306,
#  'WOODLANDS ST 13': 307,
#  'WOODLANDS ST 31': 308,
#  'WOODLANDS AVE 1': 309,
#  'WOODLANDS ST 41': 310,
#  'MARSILING RISE': 311,
#  'WOODLANDS AVE 4': 312,
#  'WOODLANDS ST 81': 313,
#  'WOODLANDS ST 82': 314,
#  'WOODLANDS ST 83': 315,
#  'WOODLANDS ST 11': 316,
#  'WOODLANDS ST 32': 317,
#  'WOODLANDS AVE 9': 318,
#  'MARSILING RD': 319,
#  'YISHUN AVE 11': 320,
#  'YISHUN AVE 6': 321,
#  'YISHUN CTRL': 322,
#  'YISHUN RING RD': 323,
#  'YISHUN ST 11': 324,
#  'YISHUN ST 22': 325,
#  'YISHUN ST 61': 326,
#  'YISHUN ST 81': 327,
#  'YISHUN AVE 5': 328,
#  'YISHUN ST 21': 329,
#  'YISHUN AVE 3': 330,
#  'YISHUN AVE 4': 331,
#  'YISHUN ST 71': 332,
#  'YISHUN AVE 7': 333,
#  'YISHUN AVE 9': 334,
#  'YISHUN CTRL 1': 335,
#  'YISHUN ST 72': 336,
#  'YISHUN AVE 2': 337,
#  'SILAT AVE': 338,
#  'LENGKOK BAHRU': 339,
#  'JLN RUMAH TINGGI': 340,
#  'CASHEW RD': 341,
#  'NEW MKT RD': 342,
#  'SELEGIE RD': 343,
#  'BAIN ST': 344,
#  'CHOA CHU KANG LOOP': 345,
#  "C'WEALTH AVE WEST": 346,
#  'CASSIA CRES': 347,
#  'OLD AIRPORT RD': 348,
#  'UPP SERANGOON RD': 349,
#  'JURONG WEST ST 93': 350,
#  'YUNG HO RD': 351,
#  'YUNG PING RD': 352,
#  'OWEN RD': 353,
#  "JLN MA'MOR": 354,
#  'WHAMPOA STH': 355,
#  'CAMBRIDGE RD': 356,
#  'DORSET RD': 357,
#  "C'WEALTH AVE": 358,
#  'MARGARET DR': 359,
#  "QUEEN'S CL": 360,
#  'SERANGOON CTRL DR': 361,
#  'WOODLANDS CTR RD': 362,
#  'MARSILING CRES': 363,
#  'WOODLANDS AVE 3': 364,
#  'JLN DAMAI': 365,
#  'INDUS RD': 366,
#  'TIONG BAHRU RD': 367,
#  'FARRER RD': 368,
#  'UPP CROSS ST': 369,
#  'WATERLOO ST': 370,
#  'BUFFALO RD': 371,
#  'CLEMENTI ST 14': 372,
#  'JOO CHIAT RD': 373,
#  'JLN DUA': 374,
#  'PIPIT RD': 375,
#  'YUNG LOH RD': 376,
#  'NTH BRIDGE RD': 377,
#  'BOON KENG RD': 378,
#  'TESSENSOHN RD': 379,
#  'HENDERSON RD': 380,
#  'CHIN SWEE RD': 381,
#  'JLN BERSEH': 382,
#  'CHOA CHU KANG DR': 383,
#  'CHOA CHU KANG ST 54': 384,
#  'KG KAYU RD': 385,
#  'QUEENSWAY': 386,
#  'BT BATOK WEST AVE 7': 387,
#  'REDHILL LANE': 388,
#  'JURONG WEST ST 51': 389,
#  'FRENCH RD': 390,
#  'LIM LIAK ST': 391,
#  'SIMS AVE': 392,
#  'KANG CHING RD': 393,
#  'TAH CHING RD': 394,
#  'KG ARANG RD': 395,
#  'JLN DUSUN': 396,
#  'SIMEI ST 5': 397,
#  'WOODLANDS AVE 5': 398,
#  'WOODLANDS DR 50': 399,
#  'EAST COAST RD': 400,
#  'KIM PONG RD': 401,
#  'TAO CHING RD': 402,
#  'MOULMEIN RD': 403,
#  'WOODLANDS DR 40': 404,
#  'BT MERAH LANE 1': 405,
#  'MOH GUAN TER': 406,
#  'KG BAHRU HILL': 407,
#  'SMITH ST': 408,
#  'WOODLANDS DR 70': 409,
#  'KIM CHENG ST': 410,
#  'TAMPINES ST 71': 411,
#  'WOODLANDS DR 42': 412,
#  'JLN TENTERAM': 413,
#  'SERANGOON NTH AVE 3': 414,
#  'JELAPANG RD': 415,
#  'BT BATOK ST 22': 416,
#  'HOUGANG ST 91': 417,
#  'WOODLANDS AVE 6': 418,
#  'TAMPINES ST 72': 419,
#  'WOODLANDS CIRCLE': 420,
#  'CORPORATION DR': 421,
#  'LOMPANG RD': 422,
#  'WOODLANDS DR 72': 423,
#  'SENG POH RD': 424,
#  'CHOA CHU KANG ST 64': 425,
#  'BT BATOK ST 24': 426,
#  'JLN TECK WHYE': 427,
#  'WOODLANDS CRES': 428,
#  'WOODLANDS DR 60': 429,
#  'CHANGI VILLAGE RD': 430,
#  'BT BATOK ST 25': 431,
#  'HOUGANG AVE 9': 432,
#  'JURONG WEST CTRL 1': 433,
#  'WOODLANDS RING RD': 434,
#  'CHOA CHU KANG AVE 5': 435,
#  'TOH GUAN RD': 436,
#  'JURONG WEST ST 61': 437,
#  'WOODLANDS DR 14': 438,
#  'HOUGANG ST 92': 439,
#  'CHOA CHU KANG CRES': 440,
#  'SEMBAWANG CL': 441,
#  'CANBERRA RD': 442,
#  'SEMBAWANG CRES': 443,
#  'SEMBAWANG VISTA': 444,
#  'COMPASSVALE WALK': 445,
#  'RIVERVALE ST': 446,
#  'WOODLANDS DR 62': 447,
#  'SEMBAWANG DR': 448,
#  'WOODLANDS DR 53': 449,
#  'WOODLANDS DR 52': 450,
#  'RIVERVALE WALK': 451,
#  'COMPASSVALE LANE': 452,
#  'RIVERVALE DR': 453,
#  'SENJA RD': 454,
#  'JURONG WEST ST 65': 455,
#  'RIVERVALE CRES': 456,
#  'WOODLANDS DR 44': 457,
#  'COMPASSVALE DR': 458,
#  'WOODLANDS DR 16': 459,
#  'COMPASSVALE RD': 460,
#  'WOODLANDS DR 73': 461,
#  'HOUGANG ST 31': 462,
#  'JURONG WEST ST 64': 463,
#  'GEYLANG EAST AVE 2': 464,
#  'WOODLANDS DR 71': 465,
#  'YISHUN ST 20': 466,
#  'ADMIRALTY DR': 467,
#  'COMPASSVALE ST': 468,
#  'BEDOK RESERVOIR VIEW': 469,
#  'YUNG SHENG RD': 470,
#  'ADMIRALTY LINK': 471,
#  'SENGKANG EAST WAY': 472,
#  'ANG MO KIO ST 32': 473,
#  'ANG MO KIO ST 52': 474,
#  'BOON TIONG RD': 475,
#  'JURONG WEST ST 62': 476,
#  'ANCHORVALE LINK': 477,
#  'CANBERRA LINK': 478,
#  'COMPASSVALE CRES': 479,
#  'CLEMENTI ST 12': 480,
#  'MONTREAL DR': 481,
#  'WELLINGTON CIRCLE': 482,
#  'SENGKANG EAST RD': 483,
#  'JURONG WEST AVE 3': 484,
#  'ANCHORVALE LANE': 485,
#  'REDHILL RD': 486,
#  'SENJA LINK': 487,
#  'EDGEFIELD PLAINS': 488,
#  'ANCHORVALE DR': 489,
#  'SEGAR RD': 490,
#  'FARRER PK RD': 491,
#  'PUNGGOL FIELD': 492,
#  'EDGEDALE PLAINS': 493,
#  'ANCHORVALE RD': 494,
#  'CANTONMENT CL': 495,
#  'JLN MEMBINA': 496,
#  'FERNVALE LANE': 497,
#  'JURONG WEST ST 25': 498,
#  'CLEMENTI ST 11': 499,
#  'PUNGGOL FIELD WALK': 500,
#  'KLANG LANE': 501,
#  'PUNGGOL CTRL': 502,
#  'JELEBU RD': 503,
#  'BUANGKOK CRES': 504,
#  'WOODLANDS DR 75': 505,
#  'BT BATOK WEST AVE 5': 506,
#  'JELLICOE RD': 507,
#  'PUNGGOL DR': 508,
#  'JURONG WEST ST 24': 509,
#  'SEMBAWANG WAY': 510,
#  'FERNVALE RD': 511,
#  'BUANGKOK LINK': 512,
#  'FERNVALE LINK': 513,
#  'JLN TIGA': 514,
#  'YUAN CHING RD': 515,
#  'COMPASSVALE LINK': 516,
#  'LOWER DELTA RD': 517,
#  'MARINE PARADE CTRL': 518,
#  'COMPASSVALE BOW': 519,
#  'PUNGGOL RD': 520,
#  'BEDOK CTRL': 521,
#  'PUNGGOL EAST': 522,
#  'SENGKANG CTRL': 523,
#  'HILLVIEW AVE': 524,
#  'OUTRAM PK': 525,
#  'SHORT ST': 526,
#  'HU CHING RD': 527,
#  'LIM CHU KANG RD': 528,
#  'NILE RD': 529,
#  'JLN MEMBINA BARAT': 530,
#  'BUANGKOK STH FARMWAY 1': 531,
#  'ALEXANDRA RD': 532,
#  'SEMBAWANG RD': 533,
#  'OUTRAM HILL': 534,
#  'TELOK BLANGAH ST 31': 535,
#  'CANTONMENT RD': 536,
#  'PUNGGOL PL': 537,
#  'GHIM MOH LINK': 538,
#  'JLN KAYU': 539,
#  'TAMPINES CTRL 7': 540,
#  'YISHUN ST 41': 541,
#  'SENGKANG WEST AVE': 542,
#  'SIMEI LANE': 543,
#  'LOR 1A TOA PAYOH': 544,
#  'PUNGGOL WALK': 545,
#  'SENGKANG WEST WAY': 546,
#  'BUANGKOK GREEN': 547,
#  'PUNGGOL WAY': 548,
#  'YISHUN ST 31': 549,
#  'TECK WHYE CRES': 550,
#  'MONTREAL LINK': 551,
#  'UPP SERANGOON CRES': 552,
#  'SUMANG LINK': 553,
#  'SENGKANG EAST AVE': 554,
#  'YISHUN AVE 1': 555,
#  'ANCHORVALE CRES': 556,
#  'ANCHORVALE ST': 557,
#  'TAMPINES CTRL 8': 558,
#  'YISHUN ST 51': 559,
#  'UPP SERANGOON VIEW': 560,
#  'TAMPINES AVE 1': 561,
#  'BEDOK RESERVOIR CRES': 562,
#  'ANG MO KIO ST 61': 563,
#  'DAWSON RD': 564,
#  'FERNVALE ST': 565,
#  'HOUGANG ST 32': 566,
#  'TAMPINES ST 86': 567,
#  'SUMANG WALK': 568,
#  'CHOA CHU KANG AVE 7': 569,
#  'KEAT HONG CL': 570,
#  'JURONG WEST CTRL 3': 571,
#  'KEAT HONG LINK': 572,
#  'ALJUNIED AVE 2': 573,
#  'CANBERRA CRES': 574,
#  'SUMANG LANE': 575,
#  'CANBERRA ST': 576,
#  'ANG MO KIO ST 44': 577,
#  'ANG MO KIO ST 51': 578,
#  'BT BATOK EAST AVE 6': 579,
#  'BT BATOK WEST AVE 9': 580,
#  'CANBERRA WALK': 581,
#  'WOODLANDS RISE': 582,
#  'TAMPINES ST 61': 583,
#  'YISHUN ST 43': 584}

# %%
# alter the column with the mapped numbers
df1['street_name'] = df1['street_name'].map(streets_mapping)

# Display the DataFrame
df1.head(2)
# Out:
#          town flat_type  block  street_name  floor_area_sqm flat_model  \
# 0  ANG MO KIO    3 ROOM  170.0            1            69.0   Improved
# 1  ANG MO KIO    3 ROOM  174.0            1            61.0   Improved
#
#    lease_commence_date  resale_price  remaining_lease  resale_year  \
# 0               1986.0      147000.0             68.0         2000
# 1               1986.0      144000.0             68.0         2000
#
#    resale_month  storey_lower_bound  storey_upper_bound
# 0             1                   7                   9
# 1             1                   4                   6

# %%
df1['flat_type'].unique()
# Out:
# array(['3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', '2 ROOM',
#        'MULTI GENERATION', '1 ROOM'], dtype=object)

# %%
category_mapping = {
    '1 ROOM': 1,
    '2 ROOM': 2,
    '3 ROOM': 3,
    '4 ROOM': 4,
    '5 ROOM': 5,
    'EXECUTIVE': 6,
    'MULTI GENERATION': 7
}

# alter the column with the mapped numbers
df1['flat_type'] =df1['flat_type'].map(category_mapping)

# Display the DataFrame
df1.head(2)
# Out:
#          town  flat_type  block  street_name  floor_area_sqm flat_model  \
# 0  ANG MO KIO          3  170.0            1            69.0   Improved
# 1  ANG MO KIO          3  174.0            1            61.0   Improved
#
#    lease_commence_date  resale_price  remaining_lease  resale_year  \
# 0               1986.0      147000.0             68.0         2000
# 1               1986.0      144000.0             68.0         2000
#
#    resale_month  storey_lower_bound  storey_upper_bound
# 0             1                   7                   9
# 1             1                   4                   6

# %%
# Create a mapping of 'flat_model' values to numbers
flat_model_mapping = {
    'IMPROVED': 1,
    'NEW GENERATION': 2,
    'MODEL A': 3,
    'STANDARD': 4,
    'SIMPLIFIED': 5,
    'MODEL A-MAISONETTE': 6,
    'APARTMENT': 7,
    'MAISONETTE': 8,
    'TERRACE': 9,
    '2-ROOM': 10,
    'IMPROVED-MAISONETTE': 11,
    'MULTI GENERATION': 12,
    'PREMIUM APARTMENT': 13,
    'Improved': 14,
    'New Generation': 15,
    'Model A': 16,
    'Standard': 17,
    'Apartment': 18,
    'Simplified': 19,
    'Model A-Maisonette': 20,
    'Maisonette': 21,
    'Multi Generation': 22,
    'Adjoined flat': 23,
    'Premium Apartment': 24,
    'Terrace': 25,
    'Improved-Maisonette': 26,
    'Premium Maisonette': 27,
    '2-room': 28,
    'Model A2': 29,
    'DBSS': 30,
    'Type S1': 31,
    'Type S2': 32,
    'Premium Apartment Loft': 33,
    '3Gen': 34
}

# Map 'flat_model' values to numbers
df1['flat_model'] =df1['flat_model'].map(flat_model_mapping)

# Display the DataFrame
df1.head(3)
# Out:
#          town  flat_type  block  street_name  floor_area_sqm  flat_model  \
# 0  ANG MO KIO          3  170.0            1            69.0          14
# 1  ANG MO KIO          3  174.0            1            61.0          14
# 2  ANG MO KIO          3  216.0            2            73.0          15
#
#    lease_commence_date  resale_price  remaining_lease  resale_year  \
# 0               1986.0      147000.0             68.0         2000
# 1               1986.0      144000.0             68.0         2000
# 2               1976.0      159000.0             68.0         2000
#
#    resale_month  storey_lower_bound  storey_upper_bound
# 0             1                   7                   9
# 1             1                   4                   6
# 2             1                   7                   9

# %%
# Create a mapping of 'town' values to numbers
town_mapping = {
    'ANG MO KIO': 1,
    'BEDOK': 2,
    'BISHAN': 3,
    'BUKIT BATOK': 4,
    'BUKIT MERAH': 5,
    'BUKIT TIMAH': 6,
    'CENTRAL AREA': 7,
    'CHOA CHU KANG': 8,
    'CLEMENTI': 9,
    'GEYLANG': 10,
    'HOUGANG': 11,
    'JURONG EAST': 12,
    'JURONG WEST': 13,
    'KALLANG/WHAMPOA': 14,
    'MARINE PARADE': 15,
    'QUEENSTOWN': 16,
    'SENGKANG': 17,
    'SERANGOON': 18,
    'TAMPINES': 19,
    'TOA PAYOH': 20,
    'WOODLANDS': 21,
    'YISHUN': 22,
    'LIM CHU KANG': 23,
    'SEMBAWANG': 24,
    'BUKIT PANJANG': 25,
    'PASIR RIS': 26,
    'PUNGGOL': 27
}

# Map 'town' values to numbers
df1['town'] = df1['town'].map(town_mapping)

# Display the DataFrame
df1.head(4)
# Out:
#    town  flat_type  block  street_name  floor_area_sqm  flat_model  \
# 0     1          3  170.0            1            69.0          14
# 1     1          3  174.0            1            61.0          14
# 2     1          3  216.0            2            73.0          15
# 3     1          3  215.0            2            73.0          15
#
#    lease_commence_date  resale_price  remaining_lease  resale_year  \
# 0               1986.0      147000.0             68.0         2000
# 1               1986.0      144000.0             68.0         2000
# 2               1976.0      159000.0             68.0         2000
# 3               1976.0      167000.0             68.0         2000
#
#    resale_month  storey_lower_bound  storey_upper_bound
# 0             1                   7                   9
# 1             1                   4                   6
# 2             1                   7                   9
# 3             1                   7                   9

# %%
# save the processed data for the deployment
df1.to_csv('final.csv')

# %% [markdown]
# Correlation

# %%
# correlation matrix (ranges from 1 to -1)
corrm=df1.corr()
#corrm.to_csv('corrm.csv')
corrm
# Out:
#                          town  flat_type     block  street_name  \
# town                 1.000000   0.208313  0.050267     0.687442
# flat_type            0.208313   1.000000  0.127806     0.231143
# block                0.050267   0.127806  1.000000    -0.077008
# street_name          0.687442   0.231143 -0.077008     1.000000
# floor_area_sqm       0.201102   0.954856  0.187808     0.175072
# flat_model           0.163781   0.242332 -0.003256     0.309447
# lease_commence_date  0.333020   0.407707  0.002743     0.586359
# resale_price         0.123391   0.599264 -0.083383     0.280152
# remaining_lease           NaN        NaN       NaN          NaN
# resale_year          0.123874   0.100757 -0.116867     0.297979
# resale_month         0.003880   0.003379  0.002348     0.005019
# storey_lower_bound  -0.019096   0.077410 -0.124889     0.099987
# storey_upper_bound  -0.018833   0.077741 -0.124925     0.100558
#
#                      floor_area_sqm  flat_model  lease_commence_date  \
# town                       0.201102    0.163781             0.333020
# flat_type                  0.954856    0.242332             0.407707
# block                      0.187808   -0.003256             0.002743
# street_name                0.175072    0.309447             0.586359
# floor_area_sqm             1.000000    0.200253             0.385671
# flat_model                 0.200253    1.000000             0.355596
# lease_commence_date        0.385671    0.355596             1.000000
# resale_price               0.573701    0.245786             0.544094
# remaining_lease                 NaN         NaN                  NaN
# resale_year                0.062463    0.162440             0.431438
# resale_month               0.002847    0.001489             0.003129
# storey_lower_bound         0.043664    0.020114             0.154171
# storey_upper_bound         0.043853    0.020470             0.154567
#
#                      resale_price  remaining_lease  resale_year  resale_month  \
# town                     0.123391              NaN     0.123874      0.003880
# flat_type                0.599264              NaN     0.100757      0.003379
# block                   -0.083383              NaN    -0.116867      0.002348
# street_name              0.280152              NaN     0.297979      0.005019
# floor_area_sqm           0.573701              NaN     0.062463      0.002847
# flat_model               0.245786              NaN     0.162440      0.001489
# lease_commence_date      0.544094              NaN     0.431438      0.003129
# resale_price             1.000000              NaN     0.684518      0.004631
# remaining_lease               NaN              NaN          NaN           NaN
# resale_year              0.684518              NaN     1.000000     -0.026427
# resale_month             0.004631              NaN    -0.026427      1.000000
# storey_lower_bound       0.210021              NaN     0.096775     -0.001879
# storey_upper_bound       0.212665              NaN     0.098803     -0.004313
#
#                      storey_lower_bound  storey_upper_bound
# town                          -0.019096           -0.018833
# flat_type                      0.077410            0.077741
# block                         -0.124889           -0.124925
# street_name                    0.099987            0.100558
# floor_area_sqm                 0.043664            0.043853
# flat_model                     0.020114            0.020470
# lease_commence_date            0.154171            0.154567
# resale_price                   0.210021            0.212665
# remaining_lease                     NaN                 NaN
# resale_year                    0.096775            0.098803
# resale_month                  -0.001879           -0.004313
# storey_lower_bound             1.000000            0.999277
# storey_upper_bound             0.999277            1.000000

# %% [markdown]
# Heatmap

# %%
# visualize correlation matrix in Seaborn using a heatmap
plt.figure(figsize=(16,6))
sns.heatmap(corrm,annot=True,cmap="Blues",fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# Right to Machine learning
# split

# %%
# assign feature and target variable
X = df1.drop('resale_price', axis= 1)
y = df1['resale_price']
#splitting the data into training and testing sets with the ratio of 8:2
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=72)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (741581, 12) (185396, 12) (741581,) (185396,)

# %% [markdown]
# saclling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled ,X_test_scaled
# Out:
# (array([[ 1.06893367, -0.01589367,  0.44699619, ...,  1.30530376,
#          -0.58119135, -0.58457205],
#         [-0.08497818, -1.07060928, -0.31456915, ...,  1.59868116,
#          -1.25495943, -1.25849408],
#         [ 0.68429639, -0.01589367, -0.16987173, ..., -0.45496065,
#           0.09257674,  0.08934997],
#         ...,
#         [-0.59782789, -1.07060928,  1.5741129 , ...,  1.59868116,
#           0.76634482,  0.76327199],
#         [-1.49531489, -1.07060928, -1.00378578, ...,  0.71854896,
#           0.76634482,  0.76327199],
#         [ 0.04323425, -0.01589367, -1.09898145, ..., -0.16158325,
#          -0.58119135, -0.58457205]]),
#  array([[-0.34140304, -0.01589367,  0.10429179, ..., -1.33509286,
#          -0.58119135, -0.58457205],
#         [ 1.06893367, -0.01589367,  1.31518068, ..., -1.62847026,
#           0.76634482,  0.76327199],
#         [ 0.42787153,  1.03882193, -1.1065971 , ..., -1.62847026,
#           0.76634482,  0.76327199],
#         ...,
#         [-0.72604032, -0.01589367, -0.24983609, ...,  0.71854896,
#          -0.58119135, -0.58457205],
#         [-1.49531489, -1.07060928,  0.98009193, ...,  0.13179415,
#          -0.58119135, -0.58457205],
#         [ 0.68429639,  2.09353753,  0.50792142, ...,  1.01192636,
#           0.76634482,  0.76327199]]))

# %% [markdown]
# Model_Fit

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb
from xgboost import XGBRegressor  # Use XGBRegressor for regression

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# Linear regression

# %%
linear_model = LinearRegression(fit_intercept=True) #initialise
linear_model.fit(X_train,y_train) #fit - all magic
print(linear_model.predict(X_test))     #predict
print(y_test)
# Out:
# [357094.68710737 188819.19472674 541498.9077893  ... 226580.38403235
#  146472.53579458 383164.24241043]
# 313082    272000.0
# 455947    175000.0
# 700032    470000.0
# 725128    590000.0
# 883499    638000.0
#             ...
# 720285    450000.0
# 34755     201000.0
# 446938    160000.0
# 16461     163000.0
# 474471    500000.0
# Name: resale_price, Length: 185396, dtype: float64

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.7901118027156699

# %%
from sklearn.model_selection import cross_val_score
cross_val_linear_model=cross_val_score(linear_model,X_train,y_train,cv=10).mean()
cross_val_linear_model
# Out:
# 0.7906549162656228

# %% [markdown]
# K Nearest Neighbor Regression

# %%
# Create and train the K Nearest Neighbor Regression model
knn_regressor = KNeighborsRegressor(n_neighbors=5)  # You may need to adjust the number of neighbors
knn_regressor.fit(X_train_scaled, y_train)

# Make predictions on the test set using KNN model
y_pred_knn = knn_regressor.predict(X_test_scaled)

# Calculate Mean Absolute Error (MAE)
mae_knn = mean_absolute_error(y_test, y_pred_knn)

# Calculate Mean Squared Error (MSE)
mse_knn = mean_squared_error(y_test, y_pred_knn)

# Calculate Root Mean Squared Error (RMSE)
rmse_knn = np.sqrt(mse_knn)

# Calculate R-squared (R2) Score
r2_knn = r2_score(y_test, y_pred_knn)

print("Mean Absolute Error (MAE)    :", mae_knn)
print("Mean Squared Error (MSE)     :", mse_knn)
print("Root Mean Square Error (RMSE):", rmse_knn)
print("R-squared (R2) Score         :", r2_knn)
# Out:
# Mean Absolute Error (MAE)    : 28630.5797762627
# Mean Squared Error (MSE)     : 1731872162.1387827
# Root Mean Square Error (RMSE): 41615.768191140996
# R-squared (R2) Score         : 0.9349943731199751

# %% [markdown]
# Decision Tree Regression

# %%
# Create and train the Decision Tree Regressor model
dt_regressor = DecisionTreeRegressor(max_depth=20, random_state=11)
dt_regressor.fit(X_train, y_train)

# Make predictions on the test set using Decision Tree model
y_pred_dt = dt_regressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae_dt = mean_absolute_error(y_test, y_pred_dt)

# Calculate Mean Squared Error (MSE)
mse_dt = mean_squared_error(y_test, y_pred_dt)

# Calculate Root Mean Squared Error (RMSE)
rmse_dt = np.sqrt(mse_dt)

# Calculate R-squared (R2) Score
r2_dt = r2_score(y_test, y_pred_dt)

print("Mean Absolute Error (MAE)    :", mae_dt)
print("Mean Squared Error (MSE)     :", mse_dt)
print("Root Mean Square Error (RMSE):", rmse_dt)
print("R-squared (R2) Score         :", r2_dt)
# Out:
# Mean Absolute Error (MAE)    : 17478.521769019993
# Mean Squared Error (MSE)     : 679717293.1883432
# Root Mean Square Error (RMSE): 26071.38840162417
# R-squared (R2) Score         : 0.9744868878252914

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Create and train the Random Forest Regressor model
rf_regressor = RandomForestRegressor(random_state=42)
rf_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_regressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) Score
rf_r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE)    :", mae)
print("Mean Squared Error (MSE)     :", mse)
print("Root Mean Square Error (RMSE):", rmse)
print("R-squared (R2) Score         :", rf_r2)
# Out:
# Mean Absolute Error (MAE)    : 13806.417208982462
# Mean Squared Error (MSE)     : 397058854.77913934
# Root Mean Square Error (RMSE): 19926.335708783474
# R-squared (R2) Score         : 0.985096440529821

# %% [markdown]
# Xg Boost Regression

# %%
# Create and train an XGBoost regressor
xgregressor = XGBRegressor()
xgregressor.fit(X_train, y_train)

# Make predictions
y_pred = xgregressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) Score
xgb_r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE)    :", mae)
print("Mean Squared Error (MSE)     :", mse)
print("Root Mean Square Error (RMSE):", rmse)
print("R-squared (R2) Score         :", xgb_r2)
# Out:
# Mean Absolute Error (MAE)    : 17073.058525117423
# Mean Squared Error (MSE)     : 569330121.382831
# Root Mean Square Error (RMSE): 23860.63958452981
# R-squared (R2) Score         : 0.9786302579074506

# %% [markdown]
# Finalizeing Models

# %%
models = [ 'KNeighborsRegressor','DecisionTreeRegressor', 'RandomForestRegressor', 'XGBRegressor']
score = [r2_knn,r2_dt, rf_r2, xgb_r2]

fig=px.bar(x=models, y=score,title='R_2 of Regression Models')
fig.show()

print("FINDING BEST FIT MODEL FOR EVALUATION BASED ON R_2 SCORE\n")
max_score = max(score)  # Initialize max_score with the maximum value in the score list
max_model = ""

for model, score_value in zip(models, score):
    print(model, score_value)
    if score_value == max_score:
        max_model = model

print(f"\nModel: {max_model} contain Maximum R2_Score: {max_score} ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d046fb19-486c-47af-8164-630eb060b1dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d046fb19-486c-47af-8164-630eb060b1dc")) {                    Plotly.newPlot(                        "d046fb19-486c-47af-8164-630eb060b1dc",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["KNeighborsRegressor","DecisionTreeRegressor","RandomForestRegressor","XGBRegressor"],"xaxis":"x","y":[0.9349943731199751,0.9744868878252914,0.985096440529821,0.9786302579074506],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...
# FINDING BEST FIT MODEL FOR EVALUATION BASED ON R_2 SCORE
#
# KNeighborsRegressor 0.9349943731199751
# DecisionTreeRegressor 0.9744868878252914
# RandomForestRegressor 0.985096440529821
# XGBRegressor 0.9786302579074506
#
# Model: RandomForestRegressor contain Maximum R2_Score: 0.985096440529821

# %% [markdown]
# Suggestion

# %%
rf_regressor.feature_importances_
# Out:
# array([0.0431462 , 0.05666462, 0.0131918 , 0.02285541, 0.27140291,
#        0.00746999, 0.03161536, 0.        , 0.53632981, 0.0064704 ,
#        0.00454578, 0.00630772])

# %%
sorted_idx = rf_regressor.feature_importances_.argsort()
plt.figure(figsize=(10,5))
plt.barh(df.columns[sorted_idx], rf_regressor.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.title("Feature Importance")

plt.show()

# %%
model=rf_regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0c6bf685e999> in <cell line: 1>()
# ----> 1 model=rf_regressor.fit(X_train, y_train)
#
# NameError: name 'rf_regressor' is not defined

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1f8a688cae5d> in <cell line: 1>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1f8a688cae5d> in <cell line: 1>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
import pickle


# save the model to disk
filename = 'RandomForestRegressor_model.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model, file)

print(f"Saved {filename} model to disk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e40a9ee1ccb3> in <cell line: 6>()
#       5 filename = 'RandomForestRegressor_model.pkl'
#       6 with open(filename, 'wb') as file:
# ----> 7     pickle.dump(model, file)
#       8
#       9 print(f"Saved {filename} model to disk")
#
# NameError: name 'model' is not defined

# %%
# get sample to predict the resale price
pre_df =df1.sample(n=5)
pre_df

# %%
# drop the resale price column
A = pre_df.drop('resale_price', axis = 1)

# %%
# Make predictions on the sample
pre_pred = rf_regressor.predict(A)
pre_pred
